# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Johnathon June**<br>
# My desired occupation is to be a Data Scientist or Programmer in medical or retail.

# %% [markdown]
# *I am interested in data science because I would like to be able build models of data within medical or retail. It becomes a passion when you can think of ways to find ways to save lives.*

# %% [markdown]
# ### My code is supposed to give time

# %%
from datetime import datetime

now = datetime.now()

current_time = now.strftime("%H:%M:%S")
print("Current Time =",current_time)
# Out:
# Current Time = 05:41:57

# %% [markdown]
# List of Data Science Languages<br>
# 1. Python
# 1. R
# 1. SQL
# 1. Java Script
# 1. Scala
# 1. Julia
# 1. Java

# %% [markdown]
# * TensorFlow
# * Numpy
# * Scipy
# * Pandas
# * Matplotlib
# * Keras
# * Pytorch

# %% [markdown]
# Table of Data Science Tools<br>
# |Tools|uses|open source|
# |:---------------|:---------------:|-----------|
# |Apache Spark----|Large scale Data processing|yes|
# |TensorFlow|ML&DL|yes|
# |BigML|cloud, ML|NO|
# |Hadoop|Large Data ML|yes|

# %%
x=(5+6*12)
print(x)

# %%
hours = int(input("Please enter hours:"))
minutes = hours * 60
print(minutes, " Minutes")

# %% [markdown]
# My objectives is to become better with data science and programming. The idea is to be able to help save some lives with data science. Being able to take large amounts of data and being able to come up with ways to make the world better is exciting.

# %%
|Author|Date Created|Discription|
|:-----|:-----:|------:|
|Johnathon June|03-13-23|Test notebook|
